# %%
{
	"metadata": {
		"language_info": {
			"name": "python"
		}
	},
	"nbformat": 4,
	"nbformat_minor": 5
}

{
	"execution_count": null,
	"id": "893ac3c7",
	"metadata": {
		"vscode": {
			"languageId": "plaintext"
		}
	}
}
